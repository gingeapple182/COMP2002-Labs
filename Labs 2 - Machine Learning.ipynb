# %% [markdown]
# # Week 2 - Machine Learning

# %% [markdown]
# ## Exercise 1 - Decision trees by hand

# %% [markdown]
# This question relates to the plots below:
# ![image.png](attachment:image.png)
# <br/> a. Sketch the tree corresponding to the partition of the predictor space illustrated in the left-hand panel of the figure shown above. The numbers inside the boxes indicate the mean of *Y* within each region.
# ![image-2.png](attachment:image-2.png)
# <br/> b. Create a diagram similar to the left-hand panel of the figure above using the tree illustrated in the right-hand panel of the same figure. You should divide up the predictor space into the correct regions
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Exercise 2 - Decision Trees

# %% [markdown]
# Now you have an understanding of the mechanics of decision trees, we will now look at how we implement these. In this exercise, we will be implementing a decision tree to solve a classification problem, we can also use decision trees for regression problems and the syntax for this is very similar.

# %% [markdown]
# First, import the required modules by adding the following to the first cell in the notebook:

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
